# %% [markdown]
# # Climate Coding Challenge
#
# Climate change is impacting the way people live around the world
#
# ## Part 1: Overview
#
# Higher highs, lower lows, storms, and smoke – we’re all feeling the
# effects of climate change. In this workflow, you will take a look at
# trends in temperature over time in Boulder, CO.
#
# ### Conversation Starter:
# In a bulleted list, how is climate change affecting your home? Include references to citations that support your points, and provide a bibliography at the end of this section:
#
# *  Climate change is affecting my hometown of San Marcos, CA, (North County, San Diego) primairly by increasing the frequency and severity of both drought and heatwaves, as well as altering our precipitation regimes (Jennings, 2018; Hiro, 2022).
# * Heatwaves have become much more common in San Marcos, with temepratures hitting record highs every year and periods of intense heat lasting much longer than previous years (Jennings, 2018; Hiro, 2022).
# * Both atmospheric drought, meaning decreased rain, and agricultural drought, meaning reduced soil moisture, are becoming more common and lasitng longer, with one professsor stating weve been in a megadrought since 2000 (Hiro, 2022).
# * Precipitation regimes have change singifcantly, with much longer periods of little rain coupled with more frequent severe rainfall events that cause issues like flooding (Jennings, 2018; Hiro, 2022).
#
# ### Refrences
# * Jennings, M., Cayan, D., Kalansky, J., Pairis, A., Syphard, A., Clemesha, R., Gershunov, A., Guirguis, K., Randall, J., Stein, E., Vanderplank, S., & Gaughen, S. (2018). San Diego County ecosystems: Ecological impacts of climate change on a biodiversity hotspot [Report prepared for California's Fourth Climate Change Assessment]. California Energy Commission.
#
# * Hiro, Brian. “Ask the Experts: Drought and Climate Change in California.” CSUSM News Center, 25 Oct. 2022, https://news.csusm.edu/ask-the-experts-drought-and-climate-change-in-california/. Accessed 17 Sept. 2026.

# %% [markdown]
# ### What's going on with the code in the assignment notebooks?
#
# For this challenge, you’ll be running a scientific workflow in Python. But something’s wrong – the code won’t run! Your task is to follow the instructions below to **clean and debug** the Python code below so that it runs.
#
# **Tip:** Don’t worry if you can’t solve every bug right away. We’ll get there! If you are working on one bug for more than about 10 minutes, it’s time to ask for help.
